# %% [markdown]
#
#         ** Part 1: Python Programming**

# %%
contact_book = {'Parul' : 'parul@moringa.org',

        'Thomas' : 'thomas@moringa.org',

        'Ashley' : 'ashley@moringa.org',

        'Kellen' : 'kellen@moringa.org',

        'June' : 'june@moringa.org',

        'Joseph' : 'joe@moringa.org',

        'Lillian' : 'lillian@moringa.org',

        'Arnold' : 'arnold@moringa.org' 
}

# %%
#Delete a contact from the dictionary when the user specifies the its key 
contact_book1 = contact_book.pop("June")
print(contact_book)
# Out:
# {'Parul': 'parul@moringa.org', 'Thomas': 'thomas@moringa.org', 'Ashley': 'ashley@moringa.org', 'Kellen': 'kellen@moringa.org', 'Joseph': 'joe@moringa.org', 'Lillian': 'lillian@moringa.org', 'Arnold': 'arnold@moringa.org'}

# %%
#Print out the first 2 contacts.

contact_book1 = contact_book["Parul"]
contact_book2 = contact_book["Thomas"]
print("'Parul'", contact_book1, "'Thomas'" ,contact_book2)
# Out:
# 'Parul' parul@moringa.org 'Thomas' thomas@moringa.org

# %%
#Display the total no. of contacts left in the dictionary

print("There are", len(contact_book),"contacts in this dictionary")
# Out:
# There are 7 contacts in this dictionary

# %%
#Add 2 new contacts in the dictionary

contact_book['Nancy'] ='nancy455@moringa.org'
contact_book['Ronoh']='jamili24@moringa.org'
print(contact_book)
# Out:
# {'Parul': 'parul@moringa.org', 'Thomas': 'thomas@moringa.org', 'Ashley': 'ashley@moringa.org', 'Kellen': 'kellen@moringa.org', 'Joseph': 'joe@moringa.org', 'Lillian': 'lillian@moringa.org', 'Arnold': 'arnold@moringa.org', 'Nancy': 'nancy455@moringa.org', 'Ronoh': 'jamili24@moringa.org'}

# %%
# Print out all the contacts.

print(contact_book)
# Out:
# {'Parul': 'parul@moringa.org', 'Thomas': 'thomas@moringa.org', 'Ashley': 'ashley@moringa.org', 'Kellen': 'kellen@moringa.org', 'Joseph': 'joe@moringa.org', 'Lillian': 'lillian@moringa.org', 'Arnold': 'arnold@moringa.org', 'Nancy': 'nancy455@moringa.org', 'Ronoh': 'jamili24@moringa.org'}
